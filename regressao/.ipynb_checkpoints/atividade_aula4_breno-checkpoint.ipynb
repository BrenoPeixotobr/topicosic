# %% [markdown]
# # Disciplina: Tópicos em Inteligência Computacional
# Instituto Federal do Norte de Minas Gerais Campus Montes Claros <br/>
# Curso: Ciência da Computação <br/>
# Professora: Luciana Balieiro Cosme<br/>
# **Atividade Aula 4: REGRESSÃO** <br/>

# %%
#1. primeira ação é explorar os dados da base de dados. Quais dados são?
import csv
#import tkinter
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
tabela = pd.read_csv('bike.csv', sep=';')
tabela.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
#mostra uma quantidade maior de linhas, no caso, 10 linhas.
tabela.head(10)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
# 5        6  2011-01-01       1   0     1   5        0        6           0
# 6        7  2011-01-01       1   0     1   6        0        6           0
# 7        8  2011-01-01       1   0     1   7        0        6           0
# 8        9  2011-01-01       1   0     1   8        0        6           0
# 9       10  2011-01-01       1   0     1   9        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81     0.0000       3          13   16
# 1           1  0.22  0.2727  0.80     0.0000       8          32   40
# 2           1  0.22  0.2727  0.80     0.0000       5          27   32
# 3           1  0.24  0.2879  0.75     0.0000       3          10   13
# 4           1  0.24  0.2879  0.75     0.0000       0           1    1
# 5           2  0.24  0.2576  0.75     0.0896       0           1    1
# 6           1  0.22  0.2727  0.80     0.0000       2           0    2
# 7           1  0.20  0.2576  0.86     0.0000       1           2    3
# 8           1  0.24  0.2879  0.75     0.0000       1           7    8
# 9           1  0.32  0.3485  0.76     0.0000       8           6   14

# %%
# e o preço?
#tabela['quant'] = tabela.target
#tabela.head(10)

# %%
import matplotlib.pyplot as plt
# qual a melhor característica/columa que melhor representa o preço?

#visualmente
plt.scatter(tabela['temp'], tabela['cnt'])
plt.xlabel('Temperatura')
plt.ylabel('Quantidade de Bikes')
plt.show()

# %%
plt.scatter(tabela.temp, tabela.cnt)
plt.ylabel('Quantidade de Bikes Alugadas')
plt.xlabel('Temperatura')
plt.show()

# %%
#Métodos de correlação

tabela.corr()
# Out:
#              instant    season        yr      mnth        hr   holiday  \
# instant     1.000000  0.404046  0.866014  0.489164 -0.004775  0.014723
# season      0.404046  1.000000 -0.010742  0.830386 -0.006117 -0.009585
# yr          0.866014 -0.010742  1.000000 -0.010473 -0.003867  0.006692
# mnth        0.489164  0.830386 -0.010473  1.000000 -0.005772  0.018430
# hr         -0.004775 -0.006117 -0.003867 -0.005772  1.000000  0.000479
# holiday     0.014723 -0.009585  0.006692  0.018430  0.000479  1.000000
# weekday     0.001357 -0.002335 -0.004485  0.010400 -0.003498 -0.102088
# workingday -0.003416  0.013743 -0.002196 -0.003477  0.002285 -0.252471
# weathersit -0.014198 -0.014524 -0.019157  0.005400 -0.020203 -0.017036
# temp        0.136178  0.312025  0.040913  0.201691  0.137603 -0.027340
# atemp       0.137615  0.319380  0.039222  0.208096  0.133750 -0.030973
# hum         0.009577  0.150625 -0.083546  0.164411 -0.276498 -0.010588
# windspeed  -0.074505 -0.149773 -0.008740 -0.135386  0.137252  0.003988
# casual      0.158295  0.120206  0.142779  0.068457  0.301202  0.031564
# registered  0.282046  0.174226  0.253684  0.122273  0.374141 -0.047345
# cnt         0.278379  0.178056  0.250495  0.120638  0.394071 -0.030927
#
#              weekday  workingday  weathersit      temp     atemp       hum  \
# instant     0.001357   -0.003416   -0.014198  0.136178  0.137615  0.009577
# season     -0.002335    0.013743   -0.014524  0.312025  0.319380  0.150625
# yr         -0.004485   -0.002196   -0.019157  0.040913  0.039222 -0.083546
# mnth        0.010400   -0.003477    0.005400  0.201691  0.208096  0.164411
# hr         -0.003498    0.002285   -0.020203  0.137603  0.133750 -0.276498
# holiday    -0.102088   -0.252471   -0.017036 -0.027340 -0.030973 -0.010588
# weekday     1.000000    0.035955    0.003311 -0.001795 -0.008821 -0.037158
# workingday  0.035955    1.000000    0.044672  0.055390  0.054667  0.015688
# weathersit  0.003311    0.044672    1.000000 -0.102640 -0.105563  0.418130
# temp       -0.001795    0.055390   -0.102640  1.000000  0.987672 -0.069881
# atemp      -0.008821    0.054667   -0.105563  0.987672  1.000000 -0.051918
# hum        -0.037158    0.015688    0.418130 -0.069881 -0.051918  1.000000
# windspeed   0.011502   -0.011830    0.026226 -0.023125 -0.062336 -0.290105
# casual      0.032721   -0.300942   -0.152628  0.459616  0.454080 -0.347028
# registered  0.021578    0.134326   -0.120966  0.335361  0.332559 -0.273933
# cnt         0.026900    0.030284   -0.142426  0.404772  0.400929 -0.322911
#
#             windspeed    casual  registered       cnt
# instant     -0.074505  0.158295    0.282046  0.278379
# season      -0.149773  0.120206    0.174226  0.178056
# yr          -0.008740  0.142779    0.253684  0.250495
# mnth        -0.135386  0.068457    0.122273  0.120638
# hr           0.137252  0.301202    0.374141  0.394071
# holiday      0.003988  0.031564   -0.047345 -0.030927
# weekday      0.011502  0.032721    0.021578  0.026900
# workingday  -0.011830 -0.300942    0.134326  0.030284
# weathersit   0.026226 -0.152628   -0.120966 -0.142426
# temp        -0.023125  0.459616    0.335361  0.404772
# atemp       -0.062336  0.454080    0.332559  0.400929
# hum         -0.290105 -0.347028   -0.273933 -0.322911
# windspeed    1.000000  0.090287    0.082321  0.093234
# casual       0.090287  1.000000    0.506618  0.694564
# registered   0.082321  0.506618    1.000000  0.972151
# cnt          0.093234  0.694564    0.972151  1.000000

# %%
#resume o carregamento da base e da tabela
'''
from sklearn.datasets import load_boston
import pandas

boston = load_boston()
tabela = pandas.DataFrame(boston.data)
tabela.columns = boston.feature_names
'''

#seleciona duas colunas
X = tabela[["atemp","hr","holiday", "hum"]]

# %%
#separa dados de treinamento do modelo linear e dados para validação do modelo
#inclui o modulo de regressão linear
from sklearn import linear_model
import matplotlib.pyplot as plt

#separa em dois conjuntos, um para treinamento e outro para validação (20 últimos)
X_t = X[:-500]
X_v = X[-500:]
#print(X_t["RM"])
y_t = tabela["cnt"][:-500]
y_v = tabela["cnt"][-500:]

regr = linear_model.LinearRegression()

# treina o modelo
res=regr.fit(X_t, y_t)

# faz a predição
y_pred = regr.predict(X_v)

# coeficientes a
print('Coeficientes: \n', regr.coef_)
#intercepto b
print('Coeficientes: \n', regr.intercept_)
#y = 5.10*RM + -0.65*LSTAT + -1.24

#prediz manualmente os valores com base nos coeficientes encontrados na regressao
y_teste = 5.10*X_v["temp"] - 0.65*X_v["atemp"]- 1.24

#exibe o valor predito manualmente y_teste, que começa de 486
#exibe o valor real y_t
#exibe o valor predito pela regressão linear

#print(y_teste)
print(y_teste[16879], y_t[0],y_pred[0])

#plota todos os valores de validação
plt.scatter(X_v["atemp"], y_v,  color='black')
plt.scatter(X_v["atemp"], y_pred, color='blue')
plt.legend(["Real", "Predito"])

r2=regr.score(X_v,y_v)
print(r2)
# Out:
# Coeficientes:
#  [ 371.9790318     7.54426781  -22.05990725 -212.82392648]
# Coeficientes:
#  58.78908452739148
# 1.860085 16 85.5904505745026
# 0.18796687348528973

# %% [markdown]
# **Atividade**: Para turma A (que não fez IA), as equipes devem fazer para a base de dados Diabetes, também do sklearn.datasets, o processo de exploração dos dados, seleção de características e predição dos valores. Para a turma B(que fez IA), as equipes devem trazer outra base de dados e fazer o processo descrito acima.
#
# Para todas as equipes, cada membro deve ser responsável por uma etapa, e sua colaboração deve ser explicíta no github.

# %%
X1 = tabela[["atemp","hr","holiday", "hum"]]
#separa dados de treinamento do modelo linear e dados para validação do modelo
#inclui o modulo de regressão l
#separa em dois conjuntos, um para treinamento e outro para validação (20 últimos)
X_t1 = X1[:-500]
X_v1 = X1[-500:]
#print(X_t["RM"])
y_t1 = tabela["cnt"][:-500]
y_v1 = tabela["cnt"][-500:]

regr1 = linear_model.LinearRegression()

# treina o modelo
regr1.fit(X_t1, y_t1)

# faz a predição
y_pred1 = regr1.predict(X_v1)

# coeficientes a
print('Coeficientes: \n', regr1.coef_)
#intercepto b
print('Coeficientes: \n', regr1.intercept_)
#y = 5.10*RM + -0.65*LSTAT + -1.24

#prediz manualmente os valores com base nos coeficientes encontrados na regressao
y_teste1 = 5.10*X_v1["atemp"] - 0.65*X_v1["hr"]- 1.24

#exibe o valor predito manualmente y_teste, que começa de 486
#exibe o valor real y_t
#exibe o valor predito pela regressão linear

#print(y_teste)
print(y_teste1[16879], y_t1[0],y_pred1[0])

#plota todos os valores de validação
plt.scatter(X_v1["atemp"], y_v1,  color='black')
plt.scatter(X_v1["atemp"], y_pred1, color='blue')
plt.legend(["Real", "Predito"])

#R^2 ajustado
r2_1=regr1.score(X_v1,y_v1)
print(r2_1)
# Out:
# Coeficientes:
#  [ 371.9790318     7.54426781  -22.05990725 -212.82392648]
# Coeficientes:
#  58.78908452739148
# -0.45359000000000016 16 85.5904505745026
# 0.18796687348528973

# %%
X2 = tabela[["atemp","season","weekday","hr","holiday"]]
#separa dados de treinamento do modelo linear e dados para validação do modelo
#inclui o modulo de regressão l
#separa em dois conjuntos, um para treinamento e outro para validação (20 últimos)
X_t2 = X2[:-500]
X_v2 = X2[-500:]
#print(X_t["RM"])
y_t2 = tabela["cnt"][:-500]
y_v2 = tabela["cnt"][-500:]

regr2 = linear_model.LinearRegression()

# treina o modelo
regr2.fit(X_t2, y_t2)

# faz a predição
y_pred2 = regr2.predict(X_v2)

# coeficientes a
print('Coeficientes: \n', regr2.coef_)
#intercepto b
print('Coeficientes: \n', regr2.intercept_)
#y = 5.10*RM + -0.65*LSTAT + -1.24

#prediz manualmente os valores com base nos coeficientes encontrados na regressao
y_teste2 = 5.10*X_v2["atemp"] - 0.65*X_v2["hr"]- 1.24

#exibe o valor predito manualmente y_teste, que começa de 486
#exibe o valor real y_t
#exibe o valor predito pela regressão linear

#print(y_teste)
print(y_teste2[16879], y_t2[0],y_pred2[0])

#plota todos os valores de validação
plt.scatter(X_v2["atemp"], y_v2,  color='black')
plt.scatter(X_v2["atemp"], y_pred2, color='blue')
plt.legend(["Real", "Predito"])

#R^2 ajustado
r2_2=regr2.score(X_v2,y_v2)
print(r2_2)
# Out:
# Coeficientes:
#  [352.83004095  10.89635774   2.58168693   9.28362343 -15.76891355]
# Coeficientes:
#  -120.67808467132602
# -0.45359000000000016 16 90.98073674422545
# 0.19990617091712434

# %%
X3 = tabela[["atemp","weekday","hr","holiday","hum"]]
#separa dados de treinamento do modelo linear e dados para validação do modelo
#inclui o modulo de regressão l
#separa em dois conjuntos, um para treinamento e outro para validação (20 últimos)
X_t3 = X3[:-500]
X_v3 = X3[-500:]
#print(X_t["RM"])
y_t3 = tabela["cnt"][:-500]
y_v3 = tabela["cnt"][-500:]

regr3 = linear_model.LinearRegression()

# treina o modelo
regr3.fit(X_t3, y_t3)

# faz a predição
y_pred3 = regr3.predict(X_v3)

# coeficientes a
print('Coeficientes: \n', regr3.coef_)
#intercepto b
print('Coeficientes: \n', regr3.intercept_)
#y = 5.10*RM + -0.65*LSTAT + -1.24

#prediz manualmente os valores com base nos coeficientes encontrados na regressao
y_teste3 = 5.10*X_v3["atemp"] - 0.65*X_v3["hr"]- 1.24

#exibe o valor predito manualmente y_teste, que começa de 486
#exibe o valor real y_t
#exibe o valor predito pela regressão linear

#print(y_teste)
print(y_teste3[16879], y_t3[0],y_pred3[0])

#plota todos os valores de validação
plt.scatter(X_v3["atemp"], y_v3,  color='black')
plt.scatter(X_v3["atemp"], y_pred3, color='blue')
plt.legend(["Real", "Predito"])

#R^2 ajustado
r2_3=regr3.score(X_v3,y_v3)
print(r2_3)
# Out:
# Coeficientes:
#  [ 334.11295889   17.98560863    1.75798995    7.56390297  -21.41896974
#  -229.28043854]
# Coeficientes:
#  36.7656423294342
# -0.45359000000000016 16 112.7123847410974
# 0.29021400538577846

# %%
X4 = tabela[["atemp","hr"]]
#separa dados de treinamento do modelo linear e dados para validação do modelo
#inclui o modulo de regressão l
#separa em dois conjuntos, um para treinamento e outro para validação (20 últimos)
X_t4 = X4[:-500]
X_v4 = X4[-500:]
#print(X_t["RM"])
y_t4 = tabela["cnt"][:-500]
y_v4 = tabela["cnt"][-500:]

regr4 = linear_model.LinearRegression()

# treina o modelo
regr4.fit(X_t4, y_t4)

# faz a predição
y_pred4 = regr4.predict(X_v4)

# coeficientes a
print('Coeficientes: \n', regr4.coef_)
#intercepto b
print('Coeficientes: \n', regr4.intercept_)
#y = 5.10*RM + -0.65*LSTAT + -1.24

#prediz manualmente os valores com base nos coeficientes encontrados na regressao
y_teste4 = 5.10*X_v4["atemp"] - 0.65*X_v4["hr"]- 1.24

#exibe o valor predito manualmente y_teste, que começa de 486
#exibe o valor real y_t
#exibe o valor predito pela regressão linear

#print(y_teste)
print(y_teste4[16879], y_t4[0],y_pred4[0])

#plota todos os valores de validação
plt.scatter(X_v4["atemp"], y_v4,  color='black')
plt.scatter(X_v4["atemp"], y_pred4, color='blue')
plt.legend(["Real", "Predito"])

#R^2 ajustado
r2_4=regr4.score(X_v4,y_v4)
print(r2_4)
# Out:
# Coeficientes:
#  [375.95027021   9.19175987]
# Coeficientes:
#  -96.15141276098257
# -0.45359000000000016 16 76.03336252119334
# 0.12670381757800664

# %%
X5 = tabela[["temp","season","weekday","hr","holiday","hum"]]
#separa dados de treinamento do modelo linear e dados para validação do modelo
#inclui o modulo de regressão l
#separa em dois conjuntos, um para treinamento e outro para validação (20 últimos)
X_t5 = X5[:-500]
X_v5 = X5[-500:]
#print(X_t["RM"])
y_t5 = tabela["cnt"][:-500]
y_v5 = tabela["cnt"][-500:]

regr5 = linear_model.LinearRegression()

# treina o modelo
regr5.fit(X_t5, y_t5)

# faz a predição
y_pred5 = regr5.predict(X_v5)

# coeficientes a
print('Coeficientes: \n', regr5.coef_)
#intercepto b
print('Coeficientes: \n', regr5.intercept_)
#y = 5.10*RM + -0.65*LSTAT + -1.24

#prediz manualmente os valores com base nos coeficientes encontrados na regressao
y_teste5 = 5.10*X_v5["temp"] - 0.65*X_v5["hr"]- 1.24

#exibe o valor predito manualmente y_teste, que começa de 486
#exibe o valor real y_t
#exibe o valor predito pela regressão linear

#print(y_teste)
print(y_teste5[16879], y_t5[0],y_pred5[0])

#plota todos os valores de validação
plt.scatter(X_v5["temp"], y_v5,  color='black')
plt.scatter(X_v5["temp"], y_pred5, color='blue')
plt.legend(["Real", "Predito"])

#R^2 ajustado
r2_5=regr5.score(X_v5,y_v5)
print(r2_5)
# Out:
# Coeficientes:
#  [ 297.04053545   18.18798596    1.5790039     7.5756669   -22.95907234
#  -224.31700507]
# Coeficientes:
#  44.96484020571722
# -0.5 16 106.79311646863815
# 0.2855463857128432
